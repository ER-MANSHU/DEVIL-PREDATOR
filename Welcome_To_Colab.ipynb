# %% [markdown]
# <a href="https://colab.research.google.com/github/ER-MANSHU/DEVIL-PREDATOR/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the original image
img = mpimg.imread('/content/Screenshot 2023-03-16 201244.png')
plt.imshow(img)
plt.title('Original Image in RGB')
plt.axis('off')
plt.show()

# %%
import cv2

# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_img, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %%
# Convert the image to HSV
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(hsv_img)
plt.title('Image in HSV')
plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
